# %% [markdown]
# <a href="https://colab.research.google.com/github/DataGesare/dsc-phase-1-project/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#              **Microsoft Movie Analysis**

# %% [markdown]
#      **Overview**
#
#
#    This project will serve as the compass for navigating the diverse world of cinema, assisting in making informed decisions to ensure Microsoft's success in the competitive movie market

# %% [markdown]
#        **Business Problem**
#
#    Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
#           **Data Understanding**

# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("title.basics.csv")
df2 = pd.read_csv("bom.movie_gross.csv")
df3 = pd.read_csv("title.ratings.csv")

# %%
df1.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df2.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df3.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
to_concat = [df1, df2, df3]
movie_df = pd.concat(to_concat)

# %%
movie_df.head(5)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres title studio  \
# 0      2013.0            175.0    Action,Crime,Drama   NaN    NaN
# 1      2019.0            114.0       Biography,Drama   NaN    NaN
# 2      2018.0            122.0                 Drama   NaN    NaN
# 3      2018.0              NaN          Comedy,Drama   NaN    NaN
# 4      2017.0             80.0  Comedy,Drama,Fantasy   NaN    NaN
#
#    domestic_gross foreign_gross  year  averagerating  numvotes
# ...

# %%
movie_df.isna().sum()
# Out:
# tconst               3387
# primary_title       77243
# original_title      77264
# start_year          77243
# runtime_minutes    108982
# genres              82651
# title              220000
# studio             220005
# domestic_gross     220028
# foreign_gross      221350
# year               220000
# averagerating      149531
# numvotes           149531
# dtype: int64

# %%
movie_df.shape
# Out:
# (223387, 13)

# %%
movie_df.isna().sum()
# Out:
# tconst               3387
# primary_title       77243
# original_title      77264
# start_year          77243
# runtime_minutes         0
# genres                  0
# title              220000
# studio             220005
# domestic_gross     220028
# foreign_gross      221350
# year               220000
# averagerating           0
# numvotes                0
# dtype: int64

# %% [markdown]
#      **Data cleaning**

# %%
# Fill missing values in 'runtime_minutes' with the mean
mean= movie_df['runtime_minutes'].mean()
movie_df['runtime_minutes'].fillna(mean, inplace=True)

# %%
# Fill missing values in 'averagerating' with 0
movie_df['averagerating'].fillna(0.00000, inplace=True)

# %%
# Fill missing values in 'genres' with  'Unknown'
movie_df['genres'].fillna('Unknown', inplace=True)

# %%
# Fill missing values in 'numvotes' with 0
movie_df['numvotes'].fillna(0.00000, inplace=True)

# %%
columns_to_drop=['title','studio','domestic_gross','foreign_gross','year']
movie_df=movie_df.drop(columns = columns_to_drop)
print (movie_df)
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9805820                              NaN                         NaN
# 73852  tt9844256                              NaN                         NaN
# 73853  tt9851050                              NaN                         NaN
# 73854  tt9886934                              NaN                         NaN
# 73855  tt9894098                              NaN                         NaN
#
# ...

# %%
movie_df.isna().sum()
# Out:
# tconst              3387
# primary_title      77243
# original_title     77264
# start_year         77243
# runtime_minutes        0
# genres                 0
# averagerating          0
# numvotes               0
# dtype: int64

# %%
movie_df.sample(5)
# Out:
#           tconst              primary_title             original_title  \
# 36373  tt2327714  Butterflies of Bill Baker  Butterflies of Bill Baker
# 72839  tt4155744  Frantisek of His Own Kind      Frantisek svého druhu
# 65371  tt2265457                        NaN                        NaN
# 34873  tt1910498                        NaN                        NaN
# 71745  tt4095942   The Houses October Built   The Houses October Built
#
#        start_year  runtime_minutes              genres  averagerating  \
# 36373      2013.0        86.000000            Thriller            0.0
# 72839      2014.0        26.000000         Documentary            0.0
# 65371         NaN        86.187247             Unknown            4.8
# 34873         NaN        86.187247             Unknown            2.1
# 71745      2011.0        94.000000  Documentary,Horror            0.0
#
#        numvotes
# 36373       0.0
# 72839       0.0
# 65371      18.0
# 34873    1091.0
# 71745       0.0

# %%
movie_df.describe()
# Out:
#           start_year  runtime_minutes  domestic_gross         year  \
# count  146144.000000    223387.000000    3.359000e+03  3387.000000
# mean     2014.621798        86.187247    2.874585e+07  2013.958075
# std         2.733583       119.053750    6.698250e+07     2.478141
# min      2010.000000         1.000000    1.000000e+02  2010.000000
# 25%      2012.000000        86.000000    1.200000e+05  2012.000000
# 50%      2015.000000        86.187247    1.400000e+06  2014.000000
# 75%      2017.000000        87.000000    2.790000e+07  2016.000000
# max      2115.000000     51420.000000    9.367000e+08  2018.000000
#
#        averagerating      numvotes
# count  223387.000000  2.233870e+05
# mean        2.093721  1.164990e+03
# std         3.097517  1.749753e+04
# min         0.000000  0.000000e+00
# 25%         0.000000  0.000000e+00
# 50%         0.000000  0.000000e+00
# 75%         5.400000  1.300000e+01
# max        10.000000  1.841066e+06

# %% [markdown]
#     ** Analysis**

# %% [markdown]
#     Rating of the movies
#
#   'averagerating' is a quantitative representation of the collective opinions and preferences of viewers, serving as a crucial metric for evaluating the perceived  popularity of movies

# %%
#plot a bargraph to compare the averagerating
plt.figure(figsize=(10, 6))
movie_df['averagerating'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Number of Movie Releases by averagerating')
plt.xlabel('averagerating')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **GENRES ANALYSIS**
#
# This visualization allows for a quick understanding of the distribution of movie genres , providing insights into which genres are more prevalent and potentially more popular among the movies.Documentary and Drama are the most popular.

# %%
#plot a bargraph to compare genre
plt.figure(figsize=(14, 8))
movie_df['genres'].str.split(',', expand=True).stack().value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')

plt.title('Distribution of Movie Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Start year and Runtime minutes**
# The runtime of majority of the movies is 85-90 minutes

# %%
#plot a bargraph comparing start year and runtime minutes
plt.figure(figsize=(14, 8))

movie_df_grouped = movie_df.groupby('start_year')['runtime_minutes'].mean().reset_index()

plt.bar(movie_df_grouped['start_year'], movie_df_grouped['runtime_minutes'], color='orange', label='Average Runtime')
plt.xlabel('Start Year')
plt.ylabel('Average Runtime (minutes)')
plt.title('Comparison of Average Runtime by Start Year')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# comparing genres and averagerating
x = 'genres'
y = 'averagerating'

# Create a bar graph using Seaborn
plt.figure(figsize=(14, 8))
sns.barplot(x=x, y=y, data=movie_df, errorbar=None, palette='viridis')
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.title('Bar Graph: Average Rating by Genres')
plt.xticks(rotation=100, ha='left')
plt.show()

# %% [markdown]
# **Start_Year**
#
#  Each bar represents a range of start years, and the height of the bar indicates the frequency or count of movies that started in that particular year range.

# %%
# Create a histogram for 'start_year'
plt.figure(figsize=(10, 6))
plt.hist(movie_df['start_year'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Start Year')
plt.xlabel('Start Year')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
#
#   Average rating over time
#
#   This line plot provides a visual representation of how the average rating of movies has changed over the years. Each point on the line represents the average rating for a specific year, and the line connects these points to show the overall trend

# %%
# Line plot: Average Rating over Time
plt.figure(figsize=(14, 8))
sns.lineplot(x='start_year', y='averagerating', data=movie_df, errorbar=None, marker='o', color='blue')
plt.xlabel('Start Year')
plt.ylabel('Average Rating')
plt.title('Line Plot: Average Rating Over Time')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# **Conculusion**
#
# This analysis leads to three recommendations for Microsoft's new movie studio can use to help decide what type of films to create
#
#
# 1.  F**ocus on Popular Genres**:
#
#   Documentary and drama ar the most popular as they have a higher frequency.
#
# 2. **Consider Movie Duration**
#  Tailor movie durations to align with audience preferences-The movie duration preferred is 85-90 minutes
#
#  3.**Explore Yearly Trends**
#  Consider aligning movie production with years that show a higher concentration of successful movies or favorable trends.The years between (2005-2010)
#
#  **Next steps**
#
#
# Further analysis could yield success of Microsoft Studios
#
#  1.produce  movies by considering both quantity and quality
#
#  2.Encourage user feedback and interaction through ratings and reviews
#
#  3.Be adaptive to changes in audience preferences and and emerging technologies.
